# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv ("ecommerce_sales.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 data = pd.read_csv ("ecommerce_sales.csv")
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
data = pd.read_csv ("C:\Users\heith\Downloads\ecommerce_sales.csv")
# Out:
#   Input In [6]
#     data = pd.read_csv ("C:\Users\heith\Downloads\ecommerce_sales.csv")
#                                                                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
data = pd.read_csv ("C:/Users/heith/Downloads/ecommerce_sales.csv")

# %%
data
# Out:
#    OrderID Customer  Country     Category  Price  Quantity   OrderDate
# 0     1001    Alice  Germany  Electronics    120         1  2025-01-05
# 1     1002     John   France        Books     30         2  2025-01-08
# 2     1003     Sara  Germany     Clothing     50         3  2025-02-12
# 3     1004      Ali  Algeria  Electronics    100         1  2025-02-18
# 4     1005   Khaled  Algeria        Books     25         4  2025-03-01
# 5     1006     Lina   France     Clothing     60         2  2025-03-07
# 6     1007     Emma  Germany  Electronics    200         1  2025-04-02
# 7     1008     Omar  Algeria        Books     20         5  2025-04-12
# 8     1009     Noor  Tunisia     Clothing     70         2  2025-05-09
# 9     1010    Walid  Tunisia  Electronics    150         1  2025-05-16

# %%
data.info
# Out:
# <bound method DataFrame.info of    OrderID Customer  Country     Category  Price  Quantity   OrderDate
# 0     1001    Alice  Germany  Electronics    120         1  2025-01-05
# 1     1002     John   France        Books     30         2  2025-01-08
# 2     1003     Sara  Germany     Clothing     50         3  2025-02-12
# 3     1004      Ali  Algeria  Electronics    100         1  2025-02-18
# 4     1005   Khaled  Algeria        Books     25         4  2025-03-01
# 5     1006     Lina   France     Clothing     60         2  2025-03-07
# 6     1007     Emma  Germany  Electronics    200         1  2025-04-02
# 7     1008     Omar  Algeria        Books     20         5  2025-04-12
# 8     1009     Noor  Tunisia     Clothing     70         2  2025-05-09
# 9     1010    Walid  Tunisia  Electronics    150         1  2025-05-16>

# %%
data['revenue']=data['Price']* data ['Quantity'].sum().sort_valeus(ascending=false)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 data['revenue']=data['Price']* data ['Quantity'].sum().sort_valeus(ascending=false)
#
# AttributeError: 'numpy.int64' object has no attribute 'sort_valeus'

# %%
import numpy as np

# %%
data['revenue']=data['Price']* data ['Quantity'].sum().sort_values(ascending=false)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 data['revenue']=data['Price']* data ['Quantity'].sum().sort_valeus(ascending=false)
#
# AttributeError: 'numpy.int64' object has no attribute 'sort_valeus'

# %%
data['revenue']=data['Price']* data ['Quantity'].sum().sort_values(ascending=false)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 data['revenue']=data['Price']* data ['Quantity'].sum().sort_values(ascending=false)
#
# AttributeError: 'numpy.int64' object has no attribute 'sort_values'

# %%
data['revenue']=data['Price']* data ['Quantity']

# %%
data
# Out:
#    OrderID Customer  Country     Category  Price  Quantity   OrderDate  \
# 0     1001    Alice  Germany  Electronics    120         1  2025-01-05
# 1     1002     John   France        Books     30         2  2025-01-08
# 2     1003     Sara  Germany     Clothing     50         3  2025-02-12
# 3     1004      Ali  Algeria  Electronics    100         1  2025-02-18
# 4     1005   Khaled  Algeria        Books     25         4  2025-03-01
# 5     1006     Lina   France     Clothing     60         2  2025-03-07
# 6     1007     Emma  Germany  Electronics    200         1  2025-04-02
# 7     1008     Omar  Algeria        Books     20         5  2025-04-12
# 8     1009     Noor  Tunisia     Clothing     70         2  2025-05-09
# 9     1010    Walid  Tunisia  Electronics    150         1  2025-05-16
#
#    revenue
# 0      120
# 1       60
# 2      150
# 3      100
# 4      100
# 5      120
# 6      200
# 7      100
# 8      140
# 9      150

# %%
sales_by_country = data.groupby('Country')['revenue'].sum().sort_values(ascending=False)

# %%
data
# Out:
#    OrderID Customer  Country     Category  Price  Quantity   OrderDate  \
# 0     1001    Alice  Germany  Electronics    120         1  2025-01-05
# 1     1002     John   France        Books     30         2  2025-01-08
# 2     1003     Sara  Germany     Clothing     50         3  2025-02-12
# 3     1004      Ali  Algeria  Electronics    100         1  2025-02-18
# 4     1005   Khaled  Algeria        Books     25         4  2025-03-01
# 5     1006     Lina   France     Clothing     60         2  2025-03-07
# 6     1007     Emma  Germany  Electronics    200         1  2025-04-02
# 7     1008     Omar  Algeria        Books     20         5  2025-04-12
# 8     1009     Noor  Tunisia     Clothing     70         2  2025-05-09
# 9     1010    Walid  Tunisia  Electronics    150         1  2025-05-16
#
#    revenue
# 0      120
# 1       60
# 2      150
# 3      100
# 4      100
# 5      120
# 6      200
# 7      100
# 8      140
# 9      150

# %%
print ("\n top countries by revenue")
# Out:
#  top countries by revenue

# %%
print (sales_by_country)
# Out:
# Country
# Germany    470
# Algeria    300
# Tunisia    290
# France     180
# Name: revenue, dtype: int64

# %%
sales_by_category = data.groupby('Category')['revenue'].sum().sort_values(ascending=False)

# %%
print (sales_by_category)
# Out:
# Category
# Electronics    570
# Clothing       410
# Books          260
# Name: revenue, dtype: int64

# %%
data['OrderDate']=pd.to_datetime(data['OrderDate'])

# %%
data
# Out:
#    OrderID Customer  Country     Category  Price  Quantity  OrderDate  revenue
# 0     1001    Alice  Germany  Electronics    120         1 2025-01-05      120
# 1     1002     John   France        Books     30         2 2025-01-08       60
# 2     1003     Sara  Germany     Clothing     50         3 2025-02-12      150
# 3     1004      Ali  Algeria  Electronics    100         1 2025-02-18      100
# 4     1005   Khaled  Algeria        Books     25         4 2025-03-01      100
# 5     1006     Lina   France     Clothing     60         2 2025-03-07      120
# 6     1007     Emma  Germany  Electronics    200         1 2025-04-02      200
# 7     1008     Omar  Algeria        Books     20         5 2025-04-12      100
# 8     1009     Noor  Tunisia     Clothing     70         2 2025-05-09      140
# 9     1010    Walid  Tunisia  Electronics    150         1 2025-05-16      150

# %%
data['month']=data['OrderDate'].dt.to_period('M')

# %%
data
# Out:
#    OrderID Customer  Country     Category  Price  Quantity  OrderDate  \
# 0     1001    Alice  Germany  Electronics    120         1 2025-01-05
# 1     1002     John   France        Books     30         2 2025-01-08
# 2     1003     Sara  Germany     Clothing     50         3 2025-02-12
# 3     1004      Ali  Algeria  Electronics    100         1 2025-02-18
# 4     1005   Khaled  Algeria        Books     25         4 2025-03-01
# 5     1006     Lina   France     Clothing     60         2 2025-03-07
# 6     1007     Emma  Germany  Electronics    200         1 2025-04-02
# 7     1008     Omar  Algeria        Books     20         5 2025-04-12
# 8     1009     Noor  Tunisia     Clothing     70         2 2025-05-09
# 9     1010    Walid  Tunisia  Electronics    150         1 2025-05-16
#
#    revenue    month
# 0      120  2025-01
# 1       60  2025-01
# 2      150  2025-02
# 3      100  2025-02
# 4      100  2025-03
# 5      120  2025-03
# 6      200  2025-04
# 7      100  2025-04
# ...

# %%
monthly_sales=data.groupby('month')['revenue'].sum()

# %%
print(monthly_sales)
# Out:
# month
# 2025-01    180
# 2025-02    250
# 2025-03    220
# 2025-04    300
# 2025-05    290
# Freq: M, Name: revenue, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
monthly_sales.plot(kind='bar',color='orange')
plt.title('monthly revenu')
plt.ylabel('revenue')
plt.xlabel('month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
